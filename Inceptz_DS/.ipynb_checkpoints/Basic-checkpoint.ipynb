# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# !dir
# Out:
#  Volume in drive C is OS
#  Volume Serial Number is CC04-D10F
#
#  Directory of C:\Users\Aneetha\Desktop\Inceptz_DS
#
# 19-07-2020  14:21    <DIR>          .
# 19-07-2020  14:21    <DIR>          ..
# 19-07-2020  14:21    <DIR>          .ipynb_checkpoints
# 19-07-2020  14:21               555 Basic.ipynb
# 19-07-2020  14:20                72 Untitled.ipynb
#                2 File(s)            627 bytes
#                3 Dir(s)  472,932,356,096 bytes free

# %%
# comment

# %%
'''
multi line comment
'''

# %%
# !whoami
# Out:
# aneethalaptop\aneetha

# %%
# !pwd
# Out:
# 'pwd' is not recognized as an internal or external command,
# operable program or batch file.

# %%
import keyword
keyword.kwlist
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']

# %%
a= 1+6j
print(type(a))

# %%
ls =[1,2,'d',3,['a','c']]#0,1,2,3,4

# %%
print(ls[2])
# Out:
# d

# %%
print(ls[4][0])
# Out:
# a

# %%
print(ls[-1][1]) #reverse order
# Out:
# c

# %%
ls1 =[1,2 ,3,4,5]
ls1.sort()

# %%
ls1.append(4)

# %%
print(ls1)
# Out:
# [1, 2, 3, 4]

# %%
help(ls1.sort) #shift+tab to get the function defintion/help
# Out:
# Help on built-in function sort:
#
# sort(*, key=None, reverse=False) method of builtins.list instance
#     Stable sort *IN PLACE*.

# %%
ls1.append([5,6])  #append is used to add list

# %%
ls1.extend (1,[-1,10])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-85-fc5091185d78> in <module>
# ----> 1 ls1.extend (1,[-1,10])
#
# TypeError: extend() takes exactly one argument (2 given)

# %%
a= ls1.pop(1) #remove

# %%
print(ls1)
# Out:
# [50, 30, 40, [5, 6], 1, 5, 5, 10, -1, 10]

# %%
ls1.sort?

# %%
# ls1.extend?
ls1.extend?

# %% [markdown]
# ls1.iterable?

# %%
ls1[2:7]
# Out:
# [3, 4, 5, 5, 6]

# %%
ls1[2:7].append([11,12])

# %%
ls1[:0] =[20]  #to insert in the start before 0

# %%
ls1[5:7] =[30,40]

# %%
ls1[:5] =[50] #remove first 5 elemsnts and put the 50 in 6 pos

# %%
ls1[-4:-1]
# Out:
# [5, 10, -1]

# %%
ls1[:-2]
# Out:
# [50, 30, 40, [5, 6], 1, 5, 5, 10]

# %%
import pydoc

# %% [markdown]
# len(ls1

# %%
len(ls1)
# Out:
# 10
